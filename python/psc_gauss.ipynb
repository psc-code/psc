# %%
import matplotlib.pyplot as plt
import xarray as xr

# %matplotlib inline 
plt.rcParams['figure.figsize'] = [16, 3]

import sys
sys.path.append('/Users/kai/src/psc/python')
import psc

import logging
# logging.basicConfig(level=logging.DEBUG)

# %%
#xr.backends.plugins.guess_engine("/Users/kai/src/psc/build-mac/pfd.000000000.bp")
ds = xr.open_dataset("/Users/kai/src/psc/build-mac/gauss.000000002.bp", engine='pscadios2')
#ds

# %%
ds.dive.plot();
# Out:
# reading  dive (0, slice(None, None, None), slice(None, None, None), 0)

# %%
ds.rho.plot();
# Out:
# reading  rho (0, slice(None, None, None), slice(None, None, None), 0)

# %%
(ds.rho - ds.dive).plot()
# Out:
# reading  dive (slice(None, None, None), slice(None, None, None), slice(None, None, None), 0)
# reading  rho (slice(None, None, None), slice(None, None, None), slice(None, None, None), 0)
